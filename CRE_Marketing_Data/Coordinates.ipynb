# %% [markdown]
# # Adding Geocoding Coordinates using geopandas, geopy, and OpenStreetMap

# %%
# import geopandas
import geopy
import pandas as pd
import sys, os

# %%
formattedData = os.path.abspath('HotelOccupancyTaxData/formattedData/HOUfran.csv')
df_franchise_tax_info = pd.read_csv(formattedData)

df_franchise_tax_info.head()
# Out:
#    Taxpayer_Number                         Taxpayer_Name  \
# 0      32071548849  POP SOCKS, LIMITED LIABILITY COMPANY
# 1      32071548864        HIT, LIMITED LIABILITY COMPANY
# 2      32071691334               MODERN REAL ESTATE, LLC
# 3      32071745619                     BOBA REPUBLIC LLC
# 4      32071759388       MEDPATH HEALTHCARE SERVICES LLC
#
#                    Taxpayer_Address Taxpayer_City Taxpayer_State  \
# 0              3322 AMBER FOREST DR       HOUSTON             TX
# 1              3322 AMBER FOREST DR       HOUSTON             TX
# 2                 9918 BARR LAKE DR       HOUSTON             TX
# 3  6961 BROOKHOLLOW WEST DR STE 140       HOUSTON             TX
# 4                   13311 ARLON TRL       HOUSTON             TX
#
#    Taxpayer_Zip_Code Taxpayer_Organizational_Type  \
# 0              77068                           CL
# 1              77068                           CL
# 2              77095                           CL
# ...
