# %% [markdown]
# ## Grabing Public Hotel Occupancy Tax Data, then storing it into a database, crossreferencing if data is repeating

# %% [markdown]
# #### Prerequisites:
# ##### requirements for mysql-python communication:
# * pip install mysqlclient
# * pip install mysql-connector-python
# * if recieving wheel error: pip install wheel

# %%
# Imports
import time
import sys
from zipfile import ZipFile
import pandas as pd
import pandas.io.sql as pdsql
import glob, os
import numpy as np
# Datetime for new column
import datetime
# Imports for mySQL
from sqlalchemy import create_engine, event, DateTime
from db_setup import mysql_user, mysql_password, db_name
import mysql.connector

# %% [markdown]
# #### File path defined

# %%
mydir = os.path.abspath('./HotelOccupancyTaxData')

# %%
mydir
# Out:
# 'C:\\DataAnalyticsBootCamp\\WEEK_23 - Project 3\\Project_3_Potential_Marketing\\CRE_Marketing_Data\\HotelOccupancyTaxData'

# %% [markdown]
# ## Defining headers for data

# %%
# Defining header for marketing data. Marketing data comes with no header
# Franchise tax permit
ftact_date_head = ['Taxpayer_Number',
                   'Taxpayer_Name',
                   'Taxpayer_Address',
                   'Taxpayer_City',
                   'Taxpayer_State',
                   'Taxpayer_Zip_Code',
                   'Taxpayer_County_Code',
                   'Taxpayer_Organizational_Type',
                   'Taxpayer_Phone_Number',
                   'Record_Type_Code',
                   'Responsibility_Beginning_Date',
                   'Secretary_of_State_File_Number',
                   'SOS_Charter_Date',
                   'SOS_Status_Date',
                   'Current_Exempt_Reason_Code',
                   'Agent_Name',
                   'Agent_Address',
                   'Agent_City',
                   'Agent_State',
                   'Agent_Zip_Code']
# Franchise tax permit date
ftact_head = ['Taxpayer_Number',
              'Taxpayer_Name',
              'Taxpayer_Address',
              'Taxpayer_City',
              'Taxpayer_State',
              'Taxpayer_Zip_Code',
              'Taxpayer_County_Code',
              'Taxpayer_Organizational_Type',
              'Taxpayer_Phone_Number',
              'Record_Type_Code',
              'Responsibility_Beginning_Date',
              'Responsibility_End_Date',
              'Responsibility_End_Reason_Code',
              'Secretary_of_State_File_Number',
              'SOS_Charter_Date',
              'SOS_Status_Date',
              'SOS_Status_Code',
              'Rigth_to_Tansact_Business_Code',
              'Current_Exempt_Reason_Code',
              'Exempt_Begin_Date',
              'NAICS_Code']
# Sales tax permit
stact_head = ['Taxpayer_Number',
              'Outlet_Number',
              'Taxpayer_Name',
              'Taxpayer_Address',
              'Taxpayer_City',
              'Taxpayer_State',
              'Taxpayer_Zip_Code',
              'Taxpayer_County_Code',
              'Taxpayer_Phone_Number',
              'Taxpayer_Organizational_Type',
              'Outlet_Name',
              'Outlet_Address',
              'Outlet_City',
              'Outlet_State',
              'Outlet_Zip_Code',
              'Outlet_County_Code',
              'Outlet_Phone_Number',
              'Outlet_NAICS_Code',
              'Outlet_Inside_Outside_City_Limits_Indicator',
              'Outlet_Permit_Issue_Date',
              'Outlet_First_Sales_Date']
# Sales tax permit date
stact_date_head = ['Taxpayer_Number',
                   'Outlet_Number',
                   'Taxpayer_Name',
                   'Taxpayer_Address',
                   'Taxpayer_City',
                   'Taxpayer_State',
                   'Taxpayer_Zip_Code',
                   'Taxpayer_County_Code',
                   'Taxpayer_Phone_Number',
                   'Outlet_Name',
                   'Outlet_Address',
                   'Outlet_City',
                   'Outlet_State',
                   'Outlet_Zip_Code',
                   'Outlet_County_Code',
                   'Outlet_Phone_Number',
                   'Permit_Type',
                   'Tax_Code',
                   'Outlet_NAICS_Code',
                   'Permit_Issue_Date',
                   'First_Sale_Date']

FTOFFDIR = ['Taxpayer_Number',
            'Sequence_Number',
            'Director_Latest_Year_Filed',
            'Director_Name',
            'Director_Title',
            'Director_Address',
            'Director_City',
            'Director_State',
            'Director_Zip_Code']

# %% [markdown]
# ## Extract files from zipped folder

# %%
# extract all files
i = 0
for file in glob.glob(mydir + '/*.zip'):
    i += 1
    zip = ZipFile(file, 'r')
    print(f'Extracting file {i}')
    zip.extractall(mydir)
    zip.close()
    print('Done!')
    print(f"File {i}, extracted: {file}\n")
    time.sleep(1)
    os.remove(file)
# Out:
# Extracting file 1
# Done!
# File 1, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-06ph.zip
#
# Extracting file 2
# Done!
# File 2, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-13ph.zip
#
# Extracting file 3
# Done!
# File 3, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-21ph.zip
#
# Extracting file 4
# Done!
# File 4, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-27ph.zip
#
# Extracting file 5
# Done!
# File 5, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-03ph.zip
#
# Extracting file 6
# Done!
# File 6, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-10ph.zip
#
# Extracting file 7
# Done!
# File 7, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-18ph.zip
#
# Extracting file 8
# Done!
# File 8, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-24ph.zip
#
# Extracting file 9
# Done!
# File 9, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-02ph.zip
#
# Extracting file 10
# Done!
# File 10, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-09ph.zip
#
# Extracting file 11
# Done!
# File 11, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-16ph.zip
#
# Extracting file 12
# Done!
# File 12, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-23ph.zip
#
# Extracting file 13
# Done!
# File 13, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran11-12ph.zip
#
# Extracting file 14
# Done!
# File 14, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran11-18ph.zip
#
# Extracting file 15
# Done!
# File 15, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran11-25ph.zip
#
# Extracting file 16
# Done!
# File 16, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-02ph.zip
#
# Extracting file 17
# Done!
# File 17, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-09ph.zip
#
# Extracting file 18
# Done!
# File 18, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-16ph.zip
#
# Extracting file 19
# Done!
# File 19, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-23ph.zip
#
# Extracting file 20
# Done!
# File 20, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-30ph.zip
#
# Extracting file 21
# Done!
# File 21, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-06ph.zip
#
# Extracting file 22
# Done!
# File 22, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-13ph.zip
#
# Extracting file 23
# Done!
# File 23, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-21ph.zip
#
# Extracting file 24
# Done!
# File 24, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-27ph.zip
#
# Extracting file 25
# Done!
# File 25, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-03ph.zip
#
# Extracting file 26
# Done!
# File 26, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-10ph.zip
#
# Extracting file 27
# Done!
# File 27, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-18ph.zip
#
# Extracting file 28
# Done!
# File 28, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-24ph.zip
#
# Extracting file 29
# Done!
# File 29, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-02ph.zip
#
# Extracting file 30
# Done!
# File 30, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-09ph.zip
#
# Extracting file 31
# Done!
# File 31, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-16ph.zip
#
# Extracting file 32
# Done!
# File 32, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-23ph.zip
#
# Extracting file 33
# Done!
# File 33, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp11-12ph.zip
#
# Extracting file 34
# Done!
# File 34, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp11-18ph.zip
#
# Extracting file 35
# Done!
# File 35, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp11-25ph.zip
#
# Extracting file 36
# Done!
# File 36, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-02ph.zip
#
# Extracting file 37
# Done!
# File 37, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-09ph.zip
#
# Extracting file 38
# Done!
# File 38, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-16ph.zip
#
# Extracting file 39
# Done!
# File 39, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-23ph.zip
#
# Extracting file 40
# Done!
# File 40, extracted: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-30ph.zip

# %% [markdown]
# ## Add csv files to a data frame ( fran and stp)

# %%
# Searches for a csv file
df_fran = pd.DataFrame()
df_stp = pd.DataFrame()

for file in glob.glob(mydir + '/*.csv'):
    if 'fran' in file:
        df = pd.read_csv(file, header=None, index_col=False, names=ftact_date_head, engine ='python')
        df_fran = df_fran.append(df)
        os.remove(file)
        print('Added the ' + file + " into the DF df_fran")
        print("deleted the file " + str(file))
    elif "stp" in file:
        df = pd.read_csv(file, header=None,index_col=False, names=stact_date_head, engine ='python')
        df_stp = df_stp.append(df)
        os.remove(file)
        print('Added the ' + file + " into the DF df_stp")
        print("deleted the file " + str(file))
    else:
        print('we do not know what to do with this file: ' + str(file))
# Out:
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-06ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-06ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-13ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-13ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-21ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-21ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-27ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran01-27ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-03ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-03ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-10ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-10ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-18ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-18ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-24ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran02-24ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-02ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-02ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-09ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-09ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-16ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-16ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-23ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran03-23ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran10-18ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran10-18ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran11-12ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran11-12ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran11-25ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran11-25ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-02ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-02ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-09ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-09ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-16ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-16ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-23ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-23ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-30ph.csv into the DF df_fran
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\fran12-30ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-06ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-06ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-13ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-13ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-21ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-21ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-27ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp01-27ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-03ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-03ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-10ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-10ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-18ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-18ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-24ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp02-24ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-02ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-02ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-09ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-09ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-16ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-16ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-23ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp03-23ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp10-18ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp10-18ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp11-12ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp11-12ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp11-25ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp11-25ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-02ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-02ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-09ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-09ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-16ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-16ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-23ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-23ph.csv
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-30ph.csv into the DF df_stp
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\stp12-30ph.csv

# %% [markdown]
# # STP DF created

# %%
df_stp.head()
# Out:
#    Taxpayer_Number Outlet_Number  \
# 0      32072900262             1
# 1      32012027135            26
# 2      32072770830             1
# 3      32066046387             2
# 4      32052228080             2
#
#                                        Taxpayer_Name  \
# 0  JAIBRYN DOMINIQUE AIKENS                      ...
# 1  FSG GROUP, L.L.C.                             ...
# 2  SNOBALL ONE INC                               ...
# 3  TEXADIA HOME TECHNOLOGIES, LLC                ...
# 4  STEVE BURKE                                   ...
#
#                            Taxpayer_Address         Taxpayer_City  \
# 0  4103 BELT LINE RD APT 255                 ADDISON
# 1  4520 NORTHAVEN RD                         DALLAS
# 2  14681 MIDWAY RD STE 200                   ADDISON
# 3  4355 EXCEL PKWY STE 600                   ADDISON
# 4  4355 EXCEL PKWY STE 600                   ADDISON
#
#   Taxpayer_State Taxpayer_Zip_Code  Taxpayer_County_Code  \
# 0             TX             75001                    57
# 1             TX             75229                    57
# 2             TX             75001                    57
# 3             TX             75001                    57
# 4             TX             75001                    57
#
#   Taxpayer_Phone_Number                                        Outlet_Name  \
# 0            5173776337  CENTERFOLD SWIM                               ...
# 1            2146498954  FSG GROUP, L.L.C.                             ...
# 2            2142124390  SNOBALL                                       ...
# 3            2149565820  TEXADIA HOME TECHNOLOGIES, LLC                ...
# 4            2149565820  TEXADIA SYSTEMS                               ...
#
#    ...           Outlet_City Outlet_State Outlet_Zip_Code Outlet_County_Code  \
# 0  ...  ADDISON                        TX           75001                057
# 1  ...  ADDISON                        TX           75001                057
# 2  ...  ADDISON                        TX           75001                057
# 3  ...  ADDISON                        TX           75001                057
# 4  ...  ADDISON                        TX           75001                057
#
#   Outlet_Phone_Number   Permit_Type Tax_Code  Outlet_NAICS_Code  \
# 0          4044683423  SALES TAX          26             454110
# 1          9725716328  SALES TAX          26             812112
# 2          2144507076  SALES TAX          26             454110
# 3          0      0    SALES TAX          26             238210
# 4          0      0    SALES TAX          26             519190
#
#   Permit_Issue_Date  First_Sale_Date
# 0          20191231         20200320
# 1          20191230         20200101
# 2          20200102         20191201
# 3          20200103         20191201
# 4          20200103         20191201
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Date format

# %%
df_stp['Permit_Issue_Date'] = df_stp['Permit_Issue_Date'].fillna(0)
df_stp['First_Sale_Date'] = df_stp['First_Sale_Date'].fillna(0)
df_stp['Outlet_Zip_Code'] = df_stp['Outlet_Zip_Code'].fillna(0)

df_stp['Permit_Issue_Date'] = df_stp['Permit_Issue_Date'].astype(np.int64)
df_stp['First_Sale_Date'] = df_stp['First_Sale_Date'].astype(np.int64)

df_stp['Permit_Issue_Date'] = pd.to_datetime(df_stp["Permit_Issue_Date"], format='%Y%m%d', errors='coerce')
df_stp['First_Sale_Date'] = pd.to_datetime(df_stp["First_Sale_Date"], format='%Y%m%d', errors='coerce')

df_stp['Permit_Issue_Date'] = df_stp['Permit_Issue_Date'].dt.normalize()
df_stp['First_Sale_Date'] = df_stp['Permit_Issue_Date'].dt.normalize()

df_stp = df_stp[df_stp['Outlet_Zip_Code']!=0]
df_stp.head()
# Out:
#    Taxpayer_Number Outlet_Number  \
# 0      32072900262             1
# 1      32012027135            26
# 2      32072770830             1
# 3      32066046387             2
# 4      32052228080             2
#
#                                        Taxpayer_Name  \
# 0  JAIBRYN DOMINIQUE AIKENS                      ...
# 1  FSG GROUP, L.L.C.                             ...
# 2  SNOBALL ONE INC                               ...
# 3  TEXADIA HOME TECHNOLOGIES, LLC                ...
# 4  STEVE BURKE                                   ...
#
#                            Taxpayer_Address         Taxpayer_City  \
# 0  4103 BELT LINE RD APT 255                 ADDISON
# 1  4520 NORTHAVEN RD                         DALLAS
# 2  14681 MIDWAY RD STE 200                   ADDISON
# 3  4355 EXCEL PKWY STE 600                   ADDISON
# 4  4355 EXCEL PKWY STE 600                   ADDISON
#
#   Taxpayer_State Taxpayer_Zip_Code  Taxpayer_County_Code  \
# 0             TX             75001                    57
# 1             TX             75229                    57
# 2             TX             75001                    57
# 3             TX             75001                    57
# 4             TX             75001                    57
#
#   Taxpayer_Phone_Number                                        Outlet_Name  \
# 0            5173776337  CENTERFOLD SWIM                               ...
# 1            2146498954  FSG GROUP, L.L.C.                             ...
# 2            2142124390  SNOBALL                                       ...
# 3            2149565820  TEXADIA HOME TECHNOLOGIES, LLC                ...
# 4            2149565820  TEXADIA SYSTEMS                               ...
#
#    ...           Outlet_City Outlet_State Outlet_Zip_Code Outlet_County_Code  \
# 0  ...  ADDISON                        TX           75001                057
# 1  ...  ADDISON                        TX           75001                057
# 2  ...  ADDISON                        TX           75001                057
# 3  ...  ADDISON                        TX           75001                057
# 4  ...  ADDISON                        TX           75001                057
#
#   Outlet_Phone_Number   Permit_Type Tax_Code  Outlet_NAICS_Code  \
# 0          4044683423  SALES TAX          26             454110
# 1          9725716328  SALES TAX          26             812112
# 2          2144507076  SALES TAX          26             454110
# 3          0      0    SALES TAX          26             238210
# 4          0      0    SALES TAX          26             519190
#
#   Permit_Issue_Date First_Sale_Date
# 0        2019-12-31      2019-12-31
# 1        2019-12-30      2019-12-30
# 2        2020-01-02      2020-01-02
# 3        2020-01-03      2020-01-03
# 4        2020-01-03      2020-01-03
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Drop any duplicates

# %%
df_stp.count()
# Out:
# Taxpayer_Number          59126
# Outlet_Number            59126
# Taxpayer_Name            59126
# Taxpayer_Address         59126
# Taxpayer_City            59126
# Taxpayer_State           59126
# Taxpayer_Zip_Code        59126
# Taxpayer_County_Code     59126
# Taxpayer_Phone_Number    59126
# Outlet_Name              59126
# Outlet_Address           59126
# Outlet_City              59126
# Outlet_State             59126
# Outlet_Zip_Code          59126
# Outlet_County_Code       59126
# Outlet_Phone_Number      59126
# Permit_Type              59126
# Tax_Code                 59126
# Outlet_NAICS_Code        59126
# Permit_Issue_Date        59126
# First_Sale_Date          59126
# dtype: int64

# %%
df_stp = df_stp.drop_duplicates(subset='Taxpayer_Number', keep='first')

# %%
df_stp.count()
# Out:
# Taxpayer_Number          54254
# Outlet_Number            54254
# Taxpayer_Name            54254
# Taxpayer_Address         54254
# Taxpayer_City            54254
# Taxpayer_State           54254
# Taxpayer_Zip_Code        54254
# Taxpayer_County_Code     54254
# Taxpayer_Phone_Number    54254
# Outlet_Name              54254
# Outlet_Address           54254
# Outlet_City              54254
# Outlet_State             54254
# Outlet_Zip_Code          54254
# Outlet_County_Code       54254
# Outlet_Phone_Number      54254
# Permit_Type              54254
# Tax_Code                 54254
# Outlet_NAICS_Code        54254
# Permit_Issue_Date        54254
# First_Sale_Date          54254
# dtype: int64

# %% [markdown]
# # FRAN DF created

# %%
df_fran.head()
# Out:
#    Taxpayer_Number                                      Taxpayer_Name  \
# 0      12020053802  KAGER INDUSTRIES, LLC                         ...
# 1      13415672842  FLAMING RIVER INDUSTRIES INC                  ...
# 2      13513654320  LA SALLE COMPANY INC                          ...
# 3      13636316849  LABSOURCE INC                                 ...
# 4      14610272230  RUSHING TRANSPORT LLC                         ...
#
#                            Taxpayer_Address         Taxpayer_City  \
# 0  3168 N STATE HIGHWAY 16                   FREDERICKSBRG
# 1  800 POERTNER DR                           BEREA
# 2  4315 RALPH JONES CT                       SOUTH BEND
# 3  1260 GARNET DR                            NORTHLAKE
# 4  7043 E CAPRICE AVE                        BATON ROUGE
#
#   Taxpayer_State Taxpayer_Zip_Code  Taxpayer_County_Code  \
# 0             TX             78624                    86
# 1             OH             44017                     0
# 2             IN             46628                     0
# 3             IL             60164                     0
# 4             LA             70811                     0
#
#   Taxpayer_Organizational_Type Taxpayer_Phone_Number Record_Type_Code  \
# 0                           CL            8309979391                U
# 1                           CF            4408264488                X
# 2                           CF            5742717644                X
# 3                           CF            6304135641                X
# 4                           CI            2252688365                X
#
#    Responsibility_Beginning_Date Secretary_of_State_File_Number  \
# 0                       20200101                     0803491095
# 1                       20200101
# 2                       20200101
# 3                       20200101
# 4                       20191220
#
#   SOS_Charter_Date SOS_Status_Date Current_Exempt_Reason_Code  \
# 0         20200101        20200101
# 1
# 2
# 3
# 4
#
#                                           Agent_Name  \
# 0  ROBERT KAGER                                  ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                               Agent_Address            Agent_City Agent_State  \
# 0  3168 NORTH STATE HWY. 16                  FREDERICKSBURG                TX
# 1
# 2
# 3
# 4
#
#   Agent_Zip_Code
# 0          78624
# 1
# 2
# 3
# 4

# %% [markdown]
# #### Adding the Taxpayer County Name and Record Type Name Column

# %%
# Taxpayer Organization Type:
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CF'),'Taxpayer_Organizational_Name']='Foreign Profit' #    CF - Foreign Profit
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CI'),'Taxpayer_Organizational_Name']='Limited Liability Company - Foreign'#   CI - Limited Liability Company - Foreign
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CL'),'Taxpayer_Organizational_Name']='Limited Liability Company - Texas' #   CL - Limited Liability Company - Texas
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CM'),'Taxpayer_Organizational_Name']='Foreign Non-Profit' #   CM - Foreign Non-Profit
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CN'),'Taxpayer_Organizational_Name']='Texas Non-Profit' #   CN - Texas Non-Profit
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CP'),'Taxpayer_Organizational_Name']='Professional' #   CP - Professional
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CR'),'Taxpayer_Organizational_Name']='Texas Insurance' #   CR - Texas Insurance
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CS'),'Taxpayer_Organizational_Name']='Foreign Insurance - OOS' #   CS - Foreign Insurance - OOS
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CT'),'Taxpayer_Organizational_Name']='Texas Profit' #   CT - Texas Profit
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CW'),'Taxpayer_Organizational_Name']='Texas Railroad Corporation' #   CW - Texas Railroad Corporation
df_fran.loc[(df_fran.Taxpayer_Organizational_Type == 'CX'),'Taxpayer_Organizational_Name']='Foreign Railroad Corporation - OOS' #   CX - Foreign Railroad Corporation - OOS
# Record Type Code:
df_fran.loc[(df_fran.Record_Type_Code == 'U'),'Record_Type_Name']='Secretary of State (SOS) File Number' #   U = Secretary of State (SOS) File Number
df_fran.loc[(df_fran.Record_Type_Code == 'V'),'Record_Type_Name']='SOS Certificate of Authority (COA) File Number' #   V = SOS Certificate of Authority (COA) File Number
df_fran.loc[(df_fran.Record_Type_Code == 'X'),'Record_Type_Name']='Comptroller Assigned File Number' #   X = Comptroller Assigned File Number
df_fran.head()
# Out:
#    Taxpayer_Number                                      Taxpayer_Name  \
# 0      12020053802  KAGER INDUSTRIES, LLC                         ...
# 1      13415672842  FLAMING RIVER INDUSTRIES INC                  ...
# 2      13513654320  LA SALLE COMPANY INC                          ...
# 3      13636316849  LABSOURCE INC                                 ...
# 4      14610272230  RUSHING TRANSPORT LLC                         ...
#
#                            Taxpayer_Address         Taxpayer_City  \
# 0  3168 N STATE HIGHWAY 16                   FREDERICKSBRG
# 1  800 POERTNER DR                           BEREA
# 2  4315 RALPH JONES CT                       SOUTH BEND
# 3  1260 GARNET DR                            NORTHLAKE
# 4  7043 E CAPRICE AVE                        BATON ROUGE
#
#   Taxpayer_State Taxpayer_Zip_Code  Taxpayer_County_Code  \
# 0             TX             78624                    86
# 1             OH             44017                     0
# 2             IN             46628                     0
# 3             IL             60164                     0
# 4             LA             70811                     0
#
#   Taxpayer_Organizational_Type Taxpayer_Phone_Number Record_Type_Code  ...  \
# 0                           CL            8309979391                U  ...
# 1                           CF            4408264488                X  ...
# 2                           CF            5742717644                X  ...
# 3                           CF            6304135641                X  ...
# 4                           CI            2252688365                X  ...
#
#    SOS_Charter_Date SOS_Status_Date Current_Exempt_Reason_Code  \
# 0          20200101        20200101
# 1
# 2
# 3
# 4
#
#                                           Agent_Name  \
# 0  ROBERT KAGER                                  ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                               Agent_Address            Agent_City Agent_State  \
# 0  3168 NORTH STATE HWY. 16                  FREDERICKSBURG                TX
# 1
# 2
# 3
# 4
#
#   Agent_Zip_Code         Taxpayer_Organizational_Name  \
# 0          78624    Limited Liability Company - Texas
# 1                                      Foreign Profit
# 2                                      Foreign Profit
# 3                                      Foreign Profit
# 4                 Limited Liability Company - Foreign
#
#                        Record_Type_Name
# 0  Secretary of State (SOS) File Number
# 1      Comptroller Assigned File Number
# 2      Comptroller Assigned File Number
# 3      Comptroller Assigned File Number
# 4      Comptroller Assigned File Number
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Date format

# %%
# df_fran['SOS_Charter_Date'] = df_fran['SOS_Charter_Date'].str.strip()

df_fran['SOS_Charter_Date'] = df_fran['SOS_Charter_Date'].fillna(0)
df_fran['SOS_Status_Date'] = df_fran['SOS_Status_Date'].fillna(0)

# df_fran['SOS_Charter_Date'] = df_fran['SOS_Charter_Date'].astype(np.int64)
# df_fran['SOS_Status_Date'] = df_fran['SOS_Status_Date'].astype(np.int64)
df_fran['Responsibility_Beginning_Date'] = df_fran['Responsibility_Beginning_Date'].astype(np.int64)

df_fran['SOS_Charter_Date'] = pd.to_datetime(df_fran["SOS_Charter_Date"], format='%Y%m%d', errors='coerce')
df_fran['SOS_Status_Date'] = pd.to_datetime(df_fran["SOS_Status_Date"], format='%Y%m%d', errors='coerce')
df_fran['Responsibility_Beginning_Date'] = pd.to_datetime(df_fran["Responsibility_Beginning_Date"], format='%Y%m%d', errors='coerce')

df_fran['SOS_Charter_Date'] =df_fran['SOS_Charter_Date'].dt.normalize()
df_fran['SOS_Status_Date'] = df_fran['SOS_Status_Date'].dt.normalize()
df_fran['Responsibility_Beginning_Date'] = df_fran['Responsibility_Beginning_Date'].dt.normalize()

df_fran = df_fran[df_fran['Taxpayer_Zip_Code']!=0]

df_fran.head()
# Out:
#    Taxpayer_Number                                      Taxpayer_Name  \
# 0      12020053802  KAGER INDUSTRIES, LLC                         ...
# 1      13415672842  FLAMING RIVER INDUSTRIES INC                  ...
# 2      13513654320  LA SALLE COMPANY INC                          ...
# 3      13636316849  LABSOURCE INC                                 ...
# 4      14610272230  RUSHING TRANSPORT LLC                         ...
#
#                            Taxpayer_Address         Taxpayer_City  \
# 0  3168 N STATE HIGHWAY 16                   FREDERICKSBRG
# 1  800 POERTNER DR                           BEREA
# 2  4315 RALPH JONES CT                       SOUTH BEND
# 3  1260 GARNET DR                            NORTHLAKE
# 4  7043 E CAPRICE AVE                        BATON ROUGE
#
#   Taxpayer_State Taxpayer_Zip_Code  Taxpayer_County_Code  \
# 0             TX             78624                    86
# 1             OH             44017                     0
# 2             IN             46628                     0
# 3             IL             60164                     0
# 4             LA             70811                     0
#
#   Taxpayer_Organizational_Type Taxpayer_Phone_Number Record_Type_Code  ...  \
# 0                           CL            8309979391                U  ...
# 1                           CF            4408264488                X  ...
# 2                           CF            5742717644                X  ...
# 3                           CF            6304135641                X  ...
# 4                           CI            2252688365                X  ...
#
#   SOS_Charter_Date SOS_Status_Date Current_Exempt_Reason_Code  \
# 0       2020-01-01      2020-01-01
# 1              NaT             NaT
# 2              NaT             NaT
# 3              NaT             NaT
# 4              NaT             NaT
#
#                                           Agent_Name  \
# 0  ROBERT KAGER                                  ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                               Agent_Address            Agent_City Agent_State  \
# 0  3168 NORTH STATE HWY. 16                  FREDERICKSBURG                TX
# 1
# 2
# 3
# 4
#
#   Agent_Zip_Code         Taxpayer_Organizational_Name  \
# 0          78624    Limited Liability Company - Texas
# 1                                      Foreign Profit
# 2                                      Foreign Profit
# 3                                      Foreign Profit
# 4                 Limited Liability Company - Foreign
#
#                        Record_Type_Name
# 0  Secretary of State (SOS) File Number
# 1      Comptroller Assigned File Number
# 2      Comptroller Assigned File Number
# 3      Comptroller Assigned File Number
# 4      Comptroller Assigned File Number
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Remove any duplicates

# %%
df_fran.count()
# Out:
# Taxpayer_Number                   269021
# Taxpayer_Name                     269021
# Taxpayer_Address                  269021
# Taxpayer_City                     269021
# Taxpayer_State                    269021
# Taxpayer_Zip_Code                 269021
# Taxpayer_County_Code              269021
# Taxpayer_Organizational_Type      269021
# Taxpayer_Phone_Number             269021
# Record_Type_Code                  269021
# Responsibility_Beginning_Date     269021
# Secretary_of_State_File_Number    269021
# SOS_Charter_Date                  260148
# SOS_Status_Date                   260148
# Current_Exempt_Reason_Code        269021
# Agent_Name                        269021
# Agent_Address                     269021
# Agent_City                        269021
# Agent_State                       269021
# Agent_Zip_Code                    269021
# Taxpayer_Organizational_Name      262696
# Record_Type_Name                  269021
# dtype: int64

# %%
df_fran = df_fran.drop_duplicates(subset='Taxpayer_Number', keep='first')

# %%
df_fran.count()
# Out:
# Taxpayer_Number                   111888
# Taxpayer_Name                     111888
# Taxpayer_Address                  111888
# Taxpayer_City                     111888
# Taxpayer_State                    111888
# Taxpayer_Zip_Code                 111888
# Taxpayer_County_Code              111888
# Taxpayer_Organizational_Type      111888
# Taxpayer_Phone_Number             111888
# Record_Type_Code                  111888
# Responsibility_Beginning_Date     111888
# Secretary_of_State_File_Number    111888
# SOS_Charter_Date                  109630
# SOS_Status_Date                   109630
# Current_Exempt_Reason_Code        111888
# Agent_Name                        111888
# Agent_Address                     111888
# Agent_City                        111888
# Agent_State                       111888
# Agent_Zip_Code                    111888
# Taxpayer_Organizational_Name      109343
# Record_Type_Name                  111888
# dtype: int64

# %% [markdown]
# ## Extracting textfile and storing into DF (FTOFFDIR, FTACT, STACT)

# %%
for file in glob.glob(mydir + '/*.txt'):
    if "FTOFFDIR" in file:
        df_ftoffdir = pd.read_fwf(file,
                                  widths=[11, 3, 4, 50, 10, 40, 20, 2, 5], header=None,
                                  names=FTOFFDIR, index_col=False)  # FTOOB, FTACT
        df_ftoffdir = df_ftoffdir.append(df_ftoffdir)
        os.remove(file)
        print('Added the ' + file + ' into df_ftoffdir')
        print('deleted the file ' + str(file))
    elif "FTOOB" in file or 'FTACT' in file:
        df_ftact = pd.read_fwf(file,
                               widths=[11, 50, 40, 20, 2, 5, 3, 2, 10, 1, 8, 8, 2, 10, 8, 8, 2, 1, 3, 8, 6],
                               header=None,
                               names=ftact_head, index_col=False, engine= 'python')  # FTOOB, FTACT
        df_ftact = df_ftact.append(df_ftact)
        os.remove(file)
        print('Added the ' + file + ' into df_ftact')
        print('deleted the file ' + str(file))

    elif "STACT" in file and 'Layout' not in file:
        df_stact = pd.read_fwf(file,
                               widths=[11, 5, 50, 40, 20, 2, 5, 3, 10, 2, 50, 40, 20, 2, 5, 3, 10, 6, 1, 8, 8],
                               header=None,
                               names=stact_head, index_col=False)  # FTOOB, FTACT
        df_stact = df_stact.append(df_stact)
        os.remove(file)
        print('Added the ' + file + ' into df_stact')
        print("deleted the file " + str(file))
    elif "CPA_SIFT_Description" in file:
        continue
    else:
        os.remove(file)
        print('File not being used: ' + str(file))
# Out:
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\FTACT.txt into df_ftact
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\FTACT.txt
# File not being used: C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\STACT Layout.txt
# Added the C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\STACT.txt into df_stact
# deleted the file C:\DataAnalyticsBootCamp\WEEK_23 - Project 3\Project_3_Potential_Marketing\CRE_Marketing_Data\HotelOccupancyTaxData\STACT.txt

# %% [markdown]
# # STACT DF created

# %%
df_stact.head()
# Out:
#    Taxpayer_Number  Outlet_Number                   Taxpayer_Name  \
# 0      10065041799              1  JOHNNY MARSHALL AND PAUL LIBBY
# 1      10100798122              1      FIASCHETTI ENTERPRISES, LP
# 2      10103759501              1    COLE HAAN COMPANY STORE, LLC
# 3      10103759501              2    COLE HAAN COMPANY STORE, LLC
# 4      10103759501              3    COLE HAAN COMPANY STORE, LLC
#
#              Taxpayer_Address Taxpayer_City Taxpayer_State  Taxpayer_Zip_Code  \
# 0            1616 LAKESIDE DR       GARLAND             TX            75042.0
# 1                 5610 5TH ST          KATY             TX            77493.0
# 2  150 OCEAN RD C/O TAX DEPT.     GREENLAND             NH             3840.0
# 3  150 OCEAN RD C/O TAX DEPT.     GREENLAND             NH             3840.0
# 4  150 OCEAN RD C/O TAX DEPT.     GREENLAND             NH             3840.0
#
#    Taxpayer_County_Code  Taxpayer_Phone_Number Taxpayer_Organizational_Type  \
# 0                    57           9.722721e+09                           PI
# 1                   101           8.329718e+09                           PL
# 2                     0           2.078463e+09                           CI
# 3                     0           2.078463e+09                           CI
# 4                     0           2.078463e+09                           CI
#
#    ...                    Outlet_Address    Outlet_City Outlet_State  \
# 0  ...                  1616 LAKESIDE DR        GARLAND           TX
# 1  ...       1830 SOUTH MASON RD STE 140           KATY           TX
# 2  ...      HIGHLAND PARK VILLAGE STE 16  HIGHLAND PARK           TX
# 3  ...  HIGHLAND VILLAGE 4005 WESTHEIMER        HOUSTON           TX
# 4  ...         3939 HWY 35 SOUTH STE 301     SAN MARCOS           TX
#
#   Outlet_Zip_Code  Outlet_County_Code  Outlet_Phone_Number Outlet_NAICS_Code  \
# 0           75042                57.0           9722720774          451120.0
# 1           77450               101.0                  NaN          722511.0
# 2           75205                57.0                  NaN          448210.0
# 3           77027               101.0           2078462500          448210.0
# 4           78666               105.0           5123960404          448210.0
#
#    Outlet_Inside_Outside_City_Limits_Indicator Outlet_Permit_Issue_Date  \
# 0                                            Y               20121022.0
# 1                                            Y               20050825.0
# 2                                            Y               19931108.0
# 3                                            Y               19941110.0
# 4                                            Y               19971212.0
#
#    Outlet_First_Sales_Date
# 0                 20120120
# 1                 20051101
# 2                 19931114
# 3                 19941118
# 4                 19980120
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Taxpayer_Organizational_Name Column

# %%
# Taxpayer Organization Type:
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'AB'),'Taxpayer_Organizational_Name']='TEXAS BUSINESS ASSOC' # AB          TEXAS BUSINESS ASSOC            
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'AC'),'Taxpayer_Organizational_Name']='FRGN BUSINESS ASSOC' # AC          FRGN BUSINESS ASSOC             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'AF'),'Taxpayer_Organizational_Name']='FOREIGN PROFESSIONAL ASSOCIATION' # AF          FOREIGN PROFESSIONAL ASSOCIATION
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'AP'),'Taxpayer_Organizational_Name']='TEXAS PROFESSIONAL ASSOCIATION' # AP          TEXAS PROFESSIONAL ASSOCIATION  
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'AR'),'Taxpayer_Organizational_Name']='OTHER ASSOCIATION' # AR          OTHER ASSOCIATION               
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'C'),'Taxpayer_Organizational_Name']='CORPORATION' # C           CORPORATION                     
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CF'),'Taxpayer_Organizational_Name']='FOREIGN PROFIT CORPORATION' # CF          FOREIGN PROFIT CORPORATION      
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CI'),'Taxpayer_Organizational_Name']='FOREIGN LMTD LIAB CO - OOS' # CI          FOREIGN LMTD LIAB CO - OOS      
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CL'),'Taxpayer_Organizational_Name']='TEXAS LIMITED LIABILITY COMPANY' # CL          TEXAS LIMITED LIABILITY COMPANY 
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CM'),'Taxpayer_Organizational_Name']='FOREIGN NON-PROFIT CORP - OOS' # CM          FOREIGN NON-PROFIT CORP - OOS   
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CN'),'Taxpayer_Organizational_Name']='TEXAS NON-PROFIT CORPORATION' # CN          TEXAS NON-PROFIT CORPORATION    
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CP'),'Taxpayer_Organizational_Name']='TEXAS PROFESSIONAL CORPORATION' # CP          TEXAS PROFESSIONAL CORPORATION
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CR'),'Taxpayer_Organizational_Name']='TEXAS INSURANCE CORPORATION' # CR          TEXAS INSURANCE CORPORATION     
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CS'),'Taxpayer_Organizational_Name']='FOREIGN INSURANCE CORP - OOS' # CS          FOREIGN INSURANCE CORP - OOS    
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CT'),'Taxpayer_Organizational_Name']='TEXAS PROFIT CORPORATION' # CT          TEXAS PROFIT CORPORATION        
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CU'),'Taxpayer_Organizational_Name']='FOREIGN PROFESSIONAL CORPORATION' # CU          FOREIGN PROFESSIONAL CORPORATION
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CW'),'Taxpayer_Organizational_Name']='TEXAS RAILROAD CORPORATION' # CW          TEXAS RAILROAD CORPORATION                          
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'CX'),'Taxpayer_Organizational_Name']='FOREIGN RAILROAD CORPORATION' # CX          FOREIGN RAILROAD CORPORATION                        
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'ES'),'Taxpayer_Organizational_Name']='ESTATE' # ES          ESTATE                                              
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FA'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE SAVINGS & LOAN - OOS' # FA          FINANCIAL INSTITUTION - STATE SAVINGS & LOAN - OOS  
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FB'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE SAVINGS B ANK - TX' # FB          FINANCIAL INSTITUTION - STATE SAVINGS B ANK - TX    
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FC'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - FEDERAL CREDIT UNION' # FC          FINANCIAL INSTITUTION - FEDERAL CREDIT UNION        
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FD'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE SAVINGS & LOAN - TX' # FD          FINANCIAL INSTITUTION - STATE SAVINGS & LOAN - TX   
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FE'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - FEDERAL SAVINGS & LOAN-TX' # FE          FINANCIAL INSTITUTION - FEDERAL SAVINGS & LOAN-TX   
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FF'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - FEDERAL BANK - TX' # FF          FINANCIAL INSTITUTION - FEDERAL BANK - TX           
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FG'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - FEDERAL SAVINGS BANK - TX' # FG          FINANCIAL INSTITUTION - FEDERAL SAVINGS BANK - TX   
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FH'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE SAVINGS BANK - OOS' # FH          FINANCIAL INSTITUTION - STATE SAVINGS BANK - OOS    
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FI'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE CREDIT UNION - TX' # FI          FINANCIAL INSTITUTION - STATE CREDIT UNION - TX     
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FJ'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - FEDERAL BANK - OOS' # FJ          FINANCIAL INSTITUTION - FEDERAL BANK - OOS          
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FK'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - FEDERAL SAVINGS BANK - OOS' # FK          FINANCIAL INSTITUTION - FEDERAL SAVINGS BANK - OOS  
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FL'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE LIMITED BANK ASSOC' # FL          FINANCIAL INSTITUTION - STATE LIMITED BANK ASSOC    
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FM'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - TRUST COMPANY' # FM          FINANCIAL INSTITUTION - TRUST COMPANY              
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FN'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - FEDERAL SAVINGS & LOAN-OOS' # FN          FINANCIAL INSTITUTION - FEDERAL SAVINGS & LOAN-OOS 
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FO'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE BANK - OOS' # FO          FINANCIAL INSTITUTION - STATE BANK - OOS           
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FP'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION' # FP          FINANCIAL INSTITUTION                              
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FR'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - FOREIGN COUNTRY BANK' # FR          FINANCIAL INSTITUTION - FOREIGN COUNTRY BANK       
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FS'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE BANK - TX' # FS          FINANCIAL INSTITUTION - STATE BANK - TX            
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'FT'),'Taxpayer_Organizational_Name']='FINANCIAL INSTITUTION - STATE CREDIT UNION - OOS' # FT          FINANCIAL INSTITUTION - STATE CREDIT UNION - OOS   
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GC'),'Taxpayer_Organizational_Name']='CITY' # GC          CITY                                               
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GD'),'Taxpayer_Organizational_Name']='FEDERAL AGENCY' # GD          FEDERAL AGENCY                                     
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GF'),'Taxpayer_Organizational_Name']='STATE AGENCY - OOS' # GF          STATE AGENCY - OOS                                 
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GJ'),'Taxpayer_Organizational_Name']='JUNIOR COLLEGE' # GJ          JUNIOR COLLEGE                                     
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GL'),'Taxpayer_Organizational_Name']='LOCAL OFFICIAL' # GL          LOCAL OFFICIAL                                     
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GM'),'Taxpayer_Organizational_Name']='MASS TRANSIT' # GM          MASS TRANSIT                                       
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GO'),'Taxpayer_Organizational_Name']='COUNTY' # GO          COUNTY                                             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GP'),'Taxpayer_Organizational_Name']='SPECIAL PURPOSE DISTRICT' # GP          SPECIAL PURPOSE DISTRICT                           
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GR'),'Taxpayer_Organizational_Name']='RAPID TRANSIT' # GR          RAPID TRANSIT              
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GS'),'Taxpayer_Organizational_Name']='SCHOOL DISTRICT' # GS          SCHOOL DISTRICT            
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GT'),'Taxpayer_Organizational_Name']='STATE AGENCY - TX' # GT          STATE AGENCY - TX          
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GU'),'Taxpayer_Organizational_Name']='STATE COLLEGE/UNIVERSITY' # GU          STATE COLLEGE/UNIVERSITY   
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'GY'),'Taxpayer_Organizational_Name']='COMMUNITY COLLEGE' # GY          COMMUNITY COLLEGE          
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'HF'),'Taxpayer_Organizational_Name']='FRGN HOLDING COMPANY' # HF          FRGN HOLDING COMPANY       
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'IS'),'Taxpayer_Organizational_Name']='INDIVIDUAL - SOLE OWNER' # IS          INDIVIDUAL - SOLE OWNER    
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'J'),'Taxpayer_Organizational_Name']=' JOINT VENTURE' # J           JOINT VENTURE              
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'L'),'Taxpayer_Organizational_Name']=' LIMITED (LIABILITY) COMPANY' # L           LIMITED (LIABILITY) COMPANY
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'M'),'Taxpayer_Organizational_Name']=' LIMITED (LIABILITY) PARTNERSHIP' # M           LIMITED (LIABILITY) PARTNERSHIP 
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'O'),'Taxpayer_Organizational_Name']=' OTHER' # O           OTHER                           
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'P'),'Taxpayer_Organizational_Name']=' GENERAL PARTNERSHIP' # P           GENERAL PARTNERSHIP             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PB'),'Taxpayer_Organizational_Name']='BUS GENERAL PRTNSHP' # PB          BUS GENERAL PRTNSHP             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PF'),'Taxpayer_Organizational_Name']='FRGN LIMITED PRTNSHP' # PF          FRGN LIMITED PRTNSHP            
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PI'),'Taxpayer_Organizational_Name']='IND GENERAL PRTNSHP' # PI          IND GENERAL PRTNSHP             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PL'),'Taxpayer_Organizational_Name']='TX LIMITED PRTNSHP' # PL          TX LIMITED PRTNSHP              
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PO'),'Taxpayer_Organizational_Name']='OIL & GAS SPECIAL' # PO          OIL & GAS SPECIAL               
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PV'),'Taxpayer_Organizational_Name']='TEXAS JOINT VENTURE' # PV          TEXAS JOINT VENTURE             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PW'),'Taxpayer_Organizational_Name']='FRGN JOINT VENTURE' # PW          FRGN JOINT VENTURE              
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PX'),'Taxpayer_Organizational_Name']='TX LLP REGISTRATION' # PX          TX LLP REGISTRATION             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PY'),'Taxpayer_Organizational_Name']='FRGN LLP REGISTRATION' # PY          FRGN LLP REGISTRATION           
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'PZ'),'Taxpayer_Organizational_Name']='IND SUCCESSOR PRTSHP' # PZ          IND SUCCESSOR PRTSHP            
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'S'),'Taxpayer_Organizational_Name']=' SOLE PROPRIETORSHIP' # S           SOLE PROPRIETORSHIP             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'SF'),'Taxpayer_Organizational_Name']='FRGN JOINT STOCK CO' # SF          FRGN JOINT STOCK CO             
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'ST'),'Taxpayer_Organizational_Name']='TEXAS JOINT STOCK CO' # ST          TEXAS JOINT STOCK CO            
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'TF'),'Taxpayer_Organizational_Name']='FOREIGN BUSINESS TRUST' # TF          FOREIGN BUSINESS TRUST               
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'TH'),'Taxpayer_Organizational_Name']='TX RL EST INV TRST' # TH          TX RL EST INV TRST                   
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'TI'),'Taxpayer_Organizational_Name']='FOREIGN REAL ESTATE INVESTMENT TRUST' # TI          FOREIGN REAL ESTATE INVESTMENT TRUST 
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'TR'),'Taxpayer_Organizational_Name']='TRUST' # TR          TRUST                                
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'UF'),'Taxpayer_Organizational_Name']='UNKNOWN - FRANCHISE' # UF          UNKNOWN - FRANCHISE                  
df_stact.loc[(df_stact.Taxpayer_Organizational_Type == 'UK'),'Taxpayer_Organizational_Name']='UNKNOWN' # UK          UNKNOWN                               
df_stact.head()
# Out:
#    Taxpayer_Number  Outlet_Number                   Taxpayer_Name  \
# 0      10065041799              1  JOHNNY MARSHALL AND PAUL LIBBY
# 1      10100798122              1      FIASCHETTI ENTERPRISES, LP
# 2      10103759501              1    COLE HAAN COMPANY STORE, LLC
# 3      10103759501              2    COLE HAAN COMPANY STORE, LLC
# 4      10103759501              3    COLE HAAN COMPANY STORE, LLC
#
#              Taxpayer_Address Taxpayer_City Taxpayer_State  Taxpayer_Zip_Code  \
# 0            1616 LAKESIDE DR       GARLAND             TX            75042.0
# 1                 5610 5TH ST          KATY             TX            77493.0
# 2  150 OCEAN RD C/O TAX DEPT.     GREENLAND             NH             3840.0
# 3  150 OCEAN RD C/O TAX DEPT.     GREENLAND             NH             3840.0
# 4  150 OCEAN RD C/O TAX DEPT.     GREENLAND             NH             3840.0
#
#    Taxpayer_County_Code  Taxpayer_Phone_Number Taxpayer_Organizational_Type  \
# 0                    57           9.722721e+09                           PI
# 1                   101           8.329718e+09                           PL
# 2                     0           2.078463e+09                           CI
# 3                     0           2.078463e+09                           CI
# 4                     0           2.078463e+09                           CI
#
#    ...    Outlet_City Outlet_State Outlet_Zip_Code Outlet_County_Code  \
# 0  ...        GARLAND           TX           75042               57.0
# 1  ...           KATY           TX           77450              101.0
# 2  ...  HIGHLAND PARK           TX           75205               57.0
# 3  ...        HOUSTON           TX           77027              101.0
# 4  ...     SAN MARCOS           TX           78666              105.0
#
#    Outlet_Phone_Number  Outlet_NAICS_Code  \
# 0           9722720774           451120.0
# 1                  NaN           722511.0
# 2                  NaN           448210.0
# 3           2078462500           448210.0
# 4           5123960404           448210.0
#
#   Outlet_Inside_Outside_City_Limits_Indicator  Outlet_Permit_Issue_Date  \
# 0                                           Y                20121022.0
# 1                                           Y                20050825.0
# 2                                           Y                19931108.0
# 3                                           Y                19941110.0
# 4                                           Y                19971212.0
#
#   Outlet_First_Sales_Date  Taxpayer_Organizational_Name
# 0                20120120           IND GENERAL PRTNSHP
# 1                20051101            TX LIMITED PRTNSHP
# 2                19931114    FOREIGN LMTD LIAB CO - OOS
# 3                19941118    FOREIGN LMTD LIAB CO - OOS
# 4                19980120    FOREIGN LMTD LIAB CO - OOS
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Formating date
# * Replacing NaN to 0, converting float to int, filtering 0, and formating date
# * formating date to datetime

# %%
df_stact['Outlet_Permit_Issue_Date'] = df_stact['Outlet_Permit_Issue_Date'].fillna(0)
df_stact['Outlet_First_Sales_Date'] = df_stact['Outlet_First_Sales_Date'].fillna(0)
df_stact['Taxpayer_Zip_Code'] = df_stact['Taxpayer_Zip_Code'].fillna(0)
df_stact['Outlet_County_Code'] = df_stact['Outlet_County_Code'].fillna(0)
df_stact['Taxpayer_Phone_Number'] = df_stact['Taxpayer_Phone_Number'].fillna(0)
df_stact['Outlet_NAICS_Code'] = df_stact['Outlet_NAICS_Code'].fillna(0)


df_stact['Outlet_Permit_Issue_Date'] = df_stact['Outlet_Permit_Issue_Date'].astype(np.int64)
df_stact['Taxpayer_Zip_Code'] = df_stact['Taxpayer_Zip_Code'].astype(np.int64)
df_stact['Outlet_County_Code'] = df_stact['Outlet_County_Code'].astype(np.int64)
df_stact['Taxpayer_Phone_Number'] = df_stact['Taxpayer_Phone_Number'].astype(np.int64)

df_stact['Outlet_Permit_Issue_Date'] = pd.to_datetime(df_stact["Outlet_Permit_Issue_Date"], format='%Y%m%d', errors='coerce')
df_stact['Outlet_First_Sales_Date'] = pd.to_datetime(df_stact["Outlet_First_Sales_Date"], format='%Y%m%d', errors='coerce')

df_stact['Outlet_First_Sales_Date'] = df_stact['Outlet_First_Sales_Date'].dt.normalize()
df_stact['Outlet_First_Sales_Date'] = df_stact['Outlet_First_Sales_Date'].dt.normalize()

df_stact = df_stact[df_stact['Taxpayer_Zip_Code']!=0]

df_stact.head(3)
# Out:
#    Taxpayer_Number  Outlet_Number                   Taxpayer_Name  \
# 0      10065041799              1  JOHNNY MARSHALL AND PAUL LIBBY
# 1      10100798122              1      FIASCHETTI ENTERPRISES, LP
# 2      10103759501              1    COLE HAAN COMPANY STORE, LLC
#
#              Taxpayer_Address Taxpayer_City Taxpayer_State  Taxpayer_Zip_Code  \
# 0            1616 LAKESIDE DR       GARLAND             TX              75042
# 1                 5610 5TH ST          KATY             TX              77493
# 2  150 OCEAN RD C/O TAX DEPT.     GREENLAND             NH               3840
#
#    Taxpayer_County_Code  Taxpayer_Phone_Number Taxpayer_Organizational_Type  \
# 0                    57             9722720774                           PI
# 1                   101             8329717661                           PL
# 2                     0             2078462626                           CI
#
#    ...    Outlet_City Outlet_State Outlet_Zip_Code Outlet_County_Code  \
# 0  ...        GARLAND           TX           75042                 57
# 1  ...           KATY           TX           77450                101
# 2  ...  HIGHLAND PARK           TX           75205                 57
#
#    Outlet_Phone_Number  Outlet_NAICS_Code  \
# 0           9722720774           451120.0
# 1                  NaN           722511.0
# 2                  NaN           448210.0
#
#   Outlet_Inside_Outside_City_Limits_Indicator  Outlet_Permit_Issue_Date  \
# 0                                           Y                2012-10-22
# 1                                           Y                2005-08-25
# 2                                           Y                1993-11-08
#
#   Outlet_First_Sales_Date Taxpayer_Organizational_Name
# 0              2012-01-20          IND GENERAL PRTNSHP
# 1              2005-11-01           TX LIMITED PRTNSHP
# 2              1993-11-14   FOREIGN LMTD LIAB CO - OOS
#
# [3 rows x 22 columns]

# %% [markdown]
# # FTACT DF created

# %%
df_ftact.head()
# Out:
#    Taxpayer_Number               Taxpayer_Name  \
# 0      10004813456  MARSHALL E HAMILTON MD PA.
# 1      10058125732        CAP INVESTMENT GROUP
# 2      10082832105          JDM RESOURCES, LTD
# 3      10100464006             CLARK INSURANCE
# 4      10100798122  FIASCHETTI ENTERPRISES, LP
#
#                   Taxpayer_Address Taxpayer_City Taxpayer_State  \
# 0  PO BOX 38206 C/O STEVE WINN CPA        DALLAS             TX
# 1           1801 HINKLE DR STE 150        DENTON             TX
# 2                 5105 BUCKLAND DR      MCKINNEY             TX
# 3           1945 CONGRESS ST STE A      PORTLAND             ME
# 4                      5610 5TH ST          KATY             TX
#
#    Taxpayer_Zip_Code  Taxpayer_County_Code Taxpayer_Organizational_Type  \
# 0            75238.0                    57                           AP
# 1            76201.0                    61                           PB
# 2            75070.0                    43                           PL
# 3             4102.0                     0                           CF
# 4            77493.0                   101                           PL
#
#   Taxpayer_Phone_Number Record_Type_Code  ...  Responsibility_End_Date  \
# 0            9726442142                X  ...                      NaN
# 1            9408914223                X  ...                      NaN
# 2            2145440124                X  ...                      NaN
# 3            2075232218                V  ...                      NaN
# 4            8329717661                U  ...                      NaN
#
#    Responsibility_End_Reason_Code  Secretary_of_State_File_Number  \
# 0                               0                             NaN
# 1                               0                             NaN
# 2                               0                             NaN
# 3                               0                     800878850.0
# 4                               0                     800242075.0
#
#    SOS_Charter_Date  SOS_Status_Date  SOS_Status_Code  \
# 0               NaN              NaN              NaN
# 1               NaN              NaN              NaN
# 2               NaN              NaN              NaN
# 3        20071001.0       20071001.0                A
# 4        20030826.0       20090520.0                R
#
#   Rigth_to_Tansact_Business_Code Current_Exempt_Reason_Code  \
# 0                              A                        NaN
# 1                              A                        NaN
# 2                              A                        NaN
# 3                              A                        NaN
# 4                              A                        NaN
#
#    Exempt_Begin_Date  NAICS_Code
# 0                NaN    621111.0
# 1                NaN    551112.0
# 2                NaN    525990.0
# 3                NaN         NaN
# 4                NaN         NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Taxpayer_Organizational_Name and Record_Type_Name Column

# %%
# Taxpayer Organization Type:
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'AB'),'Taxpayer_Organizational_Name']='Texas Business Association' #   AB – Texas Business Association
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'AC'),'Taxpayer_Organizational_Name']='Foreign Business Association' #   AC – Foreign Business Association
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'AF'),'Taxpayer_Organizational_Name']='Foreign Professional Association' #   AF – Foreign Professional Association
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'AP'),'Taxpayer_Organizational_Name']='Texas Professional Association' #   AP – Texas Professional Association
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'AR'),'Taxpayer_Organizational_Name']='Other Association' #   AR – Other Association
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CF'),'Taxpayer_Organizational_Name']='Foreign Profit' #   CF - Foreign Profit
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CI'),'Taxpayer_Organizational_Name']='Limited Liability Company - Foreign' #   CI - Limited Liability Company - Foreign
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CL'),'Taxpayer_Organizational_Name']='Limited Liability Company - Texas' #   CL - Limited Liability Company - Texas
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CM'),'Taxpayer_Organizational_Name']='Foreign Non-Profit' #   CM - Foreign Non-Profit
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CN'),'Taxpayer_Organizational_Name']='Texas Non-Profit' #   CN - Texas Non-Profit
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CP'),'Taxpayer_Organizational_Name']='Professional' #   CP - Professional
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CR'),'Taxpayer_Organizational_Name']='Texas Insurance' #   CR - Texas Insurance
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CS'),'Taxpayer_Organizational_Name']='Foreign Insurance - OOS' #   CS - Foreign Insurance - OOS
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CT'),'Taxpayer_Organizational_Name']='Texas Profit' #   CT - Texas Profit
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CU'),'Taxpayer_Organizational_Name']='Foreign Professional Corporation' #   CU – Foreign Professional Corporation
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CW'),'Taxpayer_Organizational_Name']='Texas Railroad Corporation' #   CW - Texas Railroad Corporation
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'CX'),'Taxpayer_Organizational_Name']='Foreign Railroad Corporation - OOS' #   CX - Foreign Railroad Corporation – OOS
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'HF'),'Taxpayer_Organizational_Name']='Foreign Holding Company' #   HF – Foreign Holding Company
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'PB'),'Taxpayer_Organizational_Name']='Business General Partnership' #   PB – Business General Partnership
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'PF'),'Taxpayer_Organizational_Name']='Foreign Limited Partnership' #   PF – Foreign Limited Partnership
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'PI'),'Taxpayer_Organizational_Name']='Individual General Partnership' #   PI – Individual General Partnership
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'PL'),'Taxpayer_Organizational_Name']='Texas Limited Partnership' #   PL – Texas Limited Partnership
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'PV'),'Taxpayer_Organizational_Name']='Texas Joint Venture' #   PV – Texas Joint Venture
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'PW'),'Taxpayer_Organizational_Name']='Foreign Joint Venture' #   PW – Foreign Joint Venture
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'PX'),'Taxpayer_Organizational_Name']='Texas Limited Liability Partnership' #   PX – Texas Limited Liability Partnership
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'PY'),'Taxpayer_Organizational_Name']='Foreign Limited Liability Partnerhsip' #   PY – Foreign Limited Liability Partnerhsip
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'SF'),'Taxpayer_Organizational_Name']='Foreign Joint Stock Company' #   SF – Foreign Joint Stock Company
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'ST'),'Taxpayer_Organizational_Name']='Texas Joint Stock Company' #   ST – Texas Joint Stock Company
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'TF'),'Taxpayer_Organizational_Name']='Foreign Business Trust' #   TF – Foreign Business Trust
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'TH'),'Taxpayer_Organizational_Name']='Texas Real Estate Investment Trust' #   TH – Texas Real Estate Investment Trust
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'TI'),'Taxpayer_Organizational_Name']='Foreign Real Estate Investment Trust' #   TI – Foreign Real Estate Investment Trust
df_ftact.loc[(df_ftact.Taxpayer_Organizational_Type == 'TR'),'Taxpayer_Organizational_Name']='Texas Business Trust' #   TR – Texas Business Trust
# Record Type Code:
df_ftact.loc[(df_ftact.Record_Type_Code == 'U'),'Record_Type_Name']='Secretary of State (SOS) File Number' #   U = Secretary of State (SOS) File Number
df_ftact.loc[(df_ftact.Record_Type_Code == 'V'),'Record_Type_Name']='SOS Certificate of Authority (COA) File Number' #   V = SOS Certificate of Authority (COA) File Number
df_ftact.loc[(df_ftact.Record_Type_Code == 'X'),'Record_Type_Name']='Comptroller Assigned File Number' #   X = Comptroller Assigned File Number
df_ftact.head()

# (Description for context) SOS Charter/COA:
#   Depending on the Record Type Code value, this number
#   is the SOS, COA or Comptroller Assigned File Number.
#   If the Record Type Code is an 'X', this field will be
#   blank.  They do not have a current SOS Charter/COA.
# Out:
#    Taxpayer_Number               Taxpayer_Name  \
# 0      10004813456  MARSHALL E HAMILTON MD PA.
# 1      10058125732        CAP INVESTMENT GROUP
# 2      10082832105          JDM RESOURCES, LTD
# 3      10100464006             CLARK INSURANCE
# 4      10100798122  FIASCHETTI ENTERPRISES, LP
#
#                   Taxpayer_Address Taxpayer_City Taxpayer_State  \
# 0  PO BOX 38206 C/O STEVE WINN CPA        DALLAS             TX
# 1           1801 HINKLE DR STE 150        DENTON             TX
# 2                 5105 BUCKLAND DR      MCKINNEY             TX
# 3           1945 CONGRESS ST STE A      PORTLAND             ME
# 4                      5610 5TH ST          KATY             TX
#
#    Taxpayer_Zip_Code  Taxpayer_County_Code Taxpayer_Organizational_Type  \
# 0            75238.0                    57                           AP
# 1            76201.0                    61                           PB
# 2            75070.0                    43                           PL
# 3             4102.0                     0                           CF
# 4            77493.0                   101                           PL
#
#   Taxpayer_Phone_Number Record_Type_Code  ...  Secretary_of_State_File_Number  \
# 0            9726442142                X  ...                             NaN
# 1            9408914223                X  ...                             NaN
# 2            2145440124                X  ...                             NaN
# 3            2075232218                V  ...                     800878850.0
# 4            8329717661                U  ...                     800242075.0
#
#    SOS_Charter_Date  SOS_Status_Date  SOS_Status_Code  \
# 0               NaN              NaN              NaN
# 1               NaN              NaN              NaN
# 2               NaN              NaN              NaN
# 3        20071001.0       20071001.0                A
# 4        20030826.0       20090520.0                R
#
#    Rigth_to_Tansact_Business_Code  Current_Exempt_Reason_Code  \
# 0                               A                         NaN
# 1                               A                         NaN
# 2                               A                         NaN
# 3                               A                         NaN
# 4                               A                         NaN
#
#   Exempt_Begin_Date NAICS_Code    Taxpayer_Organizational_Name  \
# 0               NaN   621111.0  Texas Professional Association
# 1               NaN   551112.0    Business General Partnership
# 2               NaN   525990.0       Texas Limited Partnership
# 3               NaN        NaN                  Foreign Profit
# 4               NaN        NaN       Texas Limited Partnership
#
#                                  Record_Type_Name
# 0                Comptroller Assigned File Number
# 1                Comptroller Assigned File Number
# 2                Comptroller Assigned File Number
# 3  SOS Certificate of Authority (COA) File Number
# 4            Secretary of State (SOS) File Number
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Responsibility_End_Reason_Name column

# %%
# Responsibility End Reason Code:
#   This is for mostly for Record Type Code value 'X'.
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 0),'Responsibility_End_Reason_Name']='Active or Inactive with no Reason Code' #     00 = Active or Inactive with no Reason Code
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 1),'Responsibility_End_Reason_Name']='Discountinued Doing Business' #     01 = Discountinued Doing Business
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 2),'Responsibility_End_Reason_Name']='Dissolved in Home State' #     02 = Dissolved in Home State
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 3),'Responsibility_End_Reason_Name']='Merged Out of Existence' #     03 = Merged Out of Existence
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 4),'Responsibility_End_Reason_Name']='Converted' #     04 = Converted
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 5),'Responsibility_End_Reason_Name']='Consolidated' #     05 = Consolidated
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 6),'Responsibility_End_Reason_Name']='Forfeited in Home State' #     06 = Forfeited in Home State
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 8),'Responsibility_End_Reason_Name']='No Nexus' #     08 = No Nexus
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 9),'Responsibility_End_Reason_Name']='No Nexus – Dates not the same' #     09 = No Nexus – Dates not the same
df_ftact.loc[(df_ftact.Responsibility_End_Reason_Code == 11),'Responsibility_End_Reason_Name']='Special Information Report' #     11 = Special Information Report
df_ftact.head()
# Out:
#    Taxpayer_Number               Taxpayer_Name  \
# 0      10004813456  MARSHALL E HAMILTON MD PA.
# 1      10058125732        CAP INVESTMENT GROUP
# 2      10082832105          JDM RESOURCES, LTD
# 3      10100464006             CLARK INSURANCE
# 4      10100798122  FIASCHETTI ENTERPRISES, LP
#
#                   Taxpayer_Address Taxpayer_City Taxpayer_State  \
# 0  PO BOX 38206 C/O STEVE WINN CPA        DALLAS             TX
# 1           1801 HINKLE DR STE 150        DENTON             TX
# 2                 5105 BUCKLAND DR      MCKINNEY             TX
# 3           1945 CONGRESS ST STE A      PORTLAND             ME
# 4                      5610 5TH ST          KATY             TX
#
#    Taxpayer_Zip_Code  Taxpayer_County_Code Taxpayer_Organizational_Type  \
# 0            75238.0                    57                           AP
# 1            76201.0                    61                           PB
# 2            75070.0                    43                           PL
# 3             4102.0                     0                           CF
# 4            77493.0                   101                           PL
#
#   Taxpayer_Phone_Number Record_Type_Code  ...  SOS_Charter_Date  \
# 0            9726442142                X  ...               NaN
# 1            9408914223                X  ...               NaN
# 2            2145440124                X  ...               NaN
# 3            2075232218                V  ...        20071001.0
# 4            8329717661                U  ...        20030826.0
#
#    SOS_Status_Date  SOS_Status_Code  Rigth_to_Tansact_Business_Code  \
# 0              NaN              NaN                               A
# 1              NaN              NaN                               A
# 2              NaN              NaN                               A
# 3       20071001.0                A                               A
# 4       20090520.0                R                               A
#
#    Current_Exempt_Reason_Code  Exempt_Begin_Date NAICS_Code  \
# 0                         NaN                NaN   621111.0
# 1                         NaN                NaN   551112.0
# 2                         NaN                NaN   525990.0
# 3                         NaN                NaN        NaN
# 4                         NaN                NaN        NaN
#
#      Taxpayer_Organizational_Name  \
# 0  Texas Professional Association
# 1    Business General Partnership
# 2       Texas Limited Partnership
# 3                  Foreign Profit
# 4       Texas Limited Partnership
#
#                                  Record_Type_Name  \
# 0                Comptroller Assigned File Number
# 1                Comptroller Assigned File Number
# 2                Comptroller Assigned File Number
# 3  SOS Certificate of Authority (COA) File Number
# 4            Secretary of State (SOS) File Number
#
#            Responsibility_End_Reason_Name
# 0  Active or Inactive with no Reason Code
# 1  Active or Inactive with no Reason Code
# 2  Active or Inactive with no Reason Code
# 3  Active or Inactive with no Reason Code
# 4  Active or Inactive with no Reason Code
#
# [5 rows x 24 columns]

# %% [markdown]
# #### SOS_Status_Name Column

# %%
# (Context description) SOS Charter/COA:
#   Depending on the Record Type Code value, this number
#   is the SOS, COA or Comptroller Assigned File Number.
#   If the Record Type Code is an 'X', this field will be
#   blank.  They do not have a current SOS Charter/COA.

# SOS Status Code:
#   For Charter/COA Numbers:
df_ftact.loc[(df_ftact.SOS_Status_Code == 'A'),'SOS_Status_Name']='Active' #     A = Active
df_ftact.loc[(df_ftact.SOS_Status_Code == 'B'),'SOS_Status_Name']='Consolidated' #     B = Consolidated
df_ftact.loc[(df_ftact.SOS_Status_Code == 'C'),'SOS_Status_Name']='Converted' #     C = Converted
df_ftact.loc[(df_ftact.SOS_Status_Code == 'D'),'SOS_Status_Name']='Dissolved' #     D = Dissolved
df_ftact.loc[(df_ftact.SOS_Status_Code == 'E'),'SOS_Status_Name']='Expired' #     E = Expired
df_ftact.loc[(df_ftact.SOS_Status_Code == 'F'),'SOS_Status_Name']='Forfeited Franchise Tax' #     F = Forfeited Franchise Tax
df_ftact.loc[(df_ftact.SOS_Status_Code == 'G'),'SOS_Status_Name']='Miscellaneous' #     G = Miscellaneous
df_ftact.loc[(df_ftact.SOS_Status_Code == 'I'),'SOS_Status_Name']='Closed by FDIC' #     I = Closed by FDIC
df_ftact.loc[(df_ftact.SOS_Status_Code == 'J'),'SOS_Status_Name']='State Charter Pulled' #     J = State Charter Pulled
df_ftact.loc[(df_ftact.SOS_Status_Code == 'K'),'SOS_Status_Name']='Forfeited Registered Agent' #     K = Forfeited Registered Agent
df_ftact.loc[(df_ftact.SOS_Status_Code == 'L'),'SOS_Status_Name']='Forfeited Registered Office' #     L = Forfeited Registered Office
df_ftact.loc[(df_ftact.SOS_Status_Code == 'M'),'SOS_Status_Name']='Merger' #     M = Merger
df_ftact.loc[(df_ftact.SOS_Status_Code == 'N'),'SOS_Status_Name']='Forfeited Hot Check' #     N = Forfeited Hot Check
df_ftact.loc[(df_ftact.SOS_Status_Code == 'P'),'SOS_Status_Name']='Forfeited Court Order' #     P = Forfeited Court Order
df_ftact.loc[(df_ftact.SOS_Status_Code == 'R'),'SOS_Status_Name']='Reinstated' #     R = Reinstated
df_ftact.loc[(df_ftact.SOS_Status_Code == 'T'),'SOS_Status_Name']='Terminated' #     T = Terminated
df_ftact.loc[(df_ftact.SOS_Status_Code == 'W'),'SOS_Status_Name']='Withdrawn' #     W = Withdrawn
df_ftact.loc[(df_ftact.SOS_Status_Code == 'Y'),'SOS_Status_Name']='Dead at Conversion 69' #     Y = Dead at Conversion 69
df_ftact.loc[(df_ftact.SOS_Status_Code == 'Z'),'SOS_Status_Name']='Dead at Conversion 83' #     Z = Dead at Conversion 83
df_ftact.head()
# Out:
#    Taxpayer_Number               Taxpayer_Name  \
# 0      10004813456  MARSHALL E HAMILTON MD PA.
# 1      10058125732        CAP INVESTMENT GROUP
# 2      10082832105          JDM RESOURCES, LTD
# 3      10100464006             CLARK INSURANCE
# 4      10100798122  FIASCHETTI ENTERPRISES, LP
#
#                   Taxpayer_Address Taxpayer_City Taxpayer_State  \
# 0  PO BOX 38206 C/O STEVE WINN CPA        DALLAS             TX
# 1           1801 HINKLE DR STE 150        DENTON             TX
# 2                 5105 BUCKLAND DR      MCKINNEY             TX
# 3           1945 CONGRESS ST STE A      PORTLAND             ME
# 4                      5610 5TH ST          KATY             TX
#
#    Taxpayer_Zip_Code  Taxpayer_County_Code Taxpayer_Organizational_Type  \
# 0            75238.0                    57                           AP
# 1            76201.0                    61                           PB
# 2            75070.0                    43                           PL
# 3             4102.0                     0                           CF
# 4            77493.0                   101                           PL
#
#   Taxpayer_Phone_Number Record_Type_Code  ...  SOS_Status_Date  \
# 0            9726442142                X  ...              NaN
# 1            9408914223                X  ...              NaN
# 2            2145440124                X  ...              NaN
# 3            2075232218                V  ...       20071001.0
# 4            8329717661                U  ...       20090520.0
#
#    SOS_Status_Code  Rigth_to_Tansact_Business_Code  \
# 0              NaN                               A
# 1              NaN                               A
# 2              NaN                               A
# 3                A                               A
# 4                R                               A
#
#    Current_Exempt_Reason_Code  Exempt_Begin_Date  NAICS_Code  \
# 0                         NaN                NaN    621111.0
# 1                         NaN                NaN    551112.0
# 2                         NaN                NaN    525990.0
# 3                         NaN                NaN         NaN
# 4                         NaN                NaN         NaN
#
#      Taxpayer_Organizational_Name  \
# 0  Texas Professional Association
# 1    Business General Partnership
# 2       Texas Limited Partnership
# 3                  Foreign Profit
# 4       Texas Limited Partnership
#
#                                  Record_Type_Name  \
# 0                Comptroller Assigned File Number
# 1                Comptroller Assigned File Number
# 2                Comptroller Assigned File Number
# 3  SOS Certificate of Authority (COA) File Number
# 4            Secretary of State (SOS) File Number
#
#            Responsibility_End_Reason_Name  SOS_Status_Name
# 0  Active or Inactive with no Reason Code              NaN
# 1  Active or Inactive with no Reason Code              NaN
# 2  Active or Inactive with no Reason Code              NaN
# 3  Active or Inactive with no Reason Code           Active
# 4  Active or Inactive with no Reason Code       Reinstated
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Rigth_to_Tansact_Business_Name Column

# %%
# Exempt Reason Code:
#   blank = Not Exempt
#   rest = Exempt for various reasons.  A list of value descriptions
#          may be requested separately.

# Right to Transact Business Code:
#   blank = Franchise Tax Ended
df_ftact.loc[(df_ftact.Rigth_to_Tansact_Business_Code == 'A'),'Rigth_to_Tansact_Business_Name']='Active' #   A = Active
df_ftact.loc[(df_ftact.Rigth_to_Tansact_Business_Code == 'D'),'Rigth_to_Tansact_Business_Name']='Active – Eligible for Termination/Withdrawl' #   D = Active – Eligible for Termination/Withdrawl
df_ftact.loc[(df_ftact.Rigth_to_Tansact_Business_Code == 'N'),'Rigth_to_Tansact_Business_Name']='Forfeited' #   N = Forfeited
df_ftact.loc[(df_ftact.Rigth_to_Tansact_Business_Code == 'I'),'Rigth_to_Tansact_Business_Name']='Franchise Tax Involuntarily Ended' #   I = Franchise Tax Involuntarily Ended
df_ftact.loc[(df_ftact.Rigth_to_Tansact_Business_Code == 'U'),'Rigth_to_Tansact_Business_Name']='Franchise Tax Not Established' #   U = Franchise Tax Not Established
df_ftact.head()
# Out:
#    Taxpayer_Number               Taxpayer_Name  \
# 0      10004813456  MARSHALL E HAMILTON MD PA.
# 1      10058125732        CAP INVESTMENT GROUP
# 2      10082832105          JDM RESOURCES, LTD
# 3      10100464006             CLARK INSURANCE
# 4      10100798122  FIASCHETTI ENTERPRISES, LP
#
#                   Taxpayer_Address Taxpayer_City Taxpayer_State  \
# 0  PO BOX 38206 C/O STEVE WINN CPA        DALLAS             TX
# 1           1801 HINKLE DR STE 150        DENTON             TX
# 2                 5105 BUCKLAND DR      MCKINNEY             TX
# 3           1945 CONGRESS ST STE A      PORTLAND             ME
# 4                      5610 5TH ST          KATY             TX
#
#    Taxpayer_Zip_Code  Taxpayer_County_Code Taxpayer_Organizational_Type  \
# 0            75238.0                    57                           AP
# 1            76201.0                    61                           PB
# 2            75070.0                    43                           PL
# 3             4102.0                     0                           CF
# 4            77493.0                   101                           PL
#
#   Taxpayer_Phone_Number Record_Type_Code  ...  SOS_Status_Code  \
# 0            9726442142                X  ...              NaN
# 1            9408914223                X  ...              NaN
# 2            2145440124                X  ...              NaN
# 3            2075232218                V  ...                A
# 4            8329717661                U  ...                R
#
#    Rigth_to_Tansact_Business_Code  Current_Exempt_Reason_Code  \
# 0                               A                         NaN
# 1                               A                         NaN
# 2                               A                         NaN
# 3                               A                         NaN
# 4                               A                         NaN
#
#    Exempt_Begin_Date  NAICS_Code    Taxpayer_Organizational_Name  \
# 0                NaN    621111.0  Texas Professional Association
# 1                NaN    551112.0    Business General Partnership
# 2                NaN    525990.0       Texas Limited Partnership
# 3                NaN         NaN                  Foreign Profit
# 4                NaN         NaN       Texas Limited Partnership
#
#                                  Record_Type_Name  \
# 0                Comptroller Assigned File Number
# 1                Comptroller Assigned File Number
# 2                Comptroller Assigned File Number
# 3  SOS Certificate of Authority (COA) File Number
# 4            Secretary of State (SOS) File Number
#
#            Responsibility_End_Reason_Name  SOS_Status_Name  \
# 0  Active or Inactive with no Reason Code              NaN
# 1  Active or Inactive with no Reason Code              NaN
# 2  Active or Inactive with no Reason Code              NaN
# 3  Active or Inactive with no Reason Code           Active
# 4  Active or Inactive with no Reason Code       Reinstated
#
#    Rigth_to_Tansact_Business_Name
# 0                          Active
# 1                          Active
# 2                          Active
# 3                          Active
# 4                          Active
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Formating data
# * changing float to int
# * adding datetime format

# %%
df_ftact['Taxpayer_Zip_Code'] = df_ftact['Taxpayer_Zip_Code'].fillna(0)
df_ftact['SOS_Charter_Date'] = df_ftact['SOS_Charter_Date'].fillna(0)
df_ftact['SOS_Status_Date'] = df_ftact['SOS_Status_Date'].fillna(0)
df_ftact['Secretary_of_State_File_Number'] = df_ftact['Secretary_of_State_File_Number'].fillna(0)
df_ftact['NAICS_Code'] = df_ftact['NAICS_Code'].fillna(0)
df_ftact['Current_Exempt_Reason_Code'] = df_ftact['Current_Exempt_Reason_Code'].fillna(0)

df_ftact['Taxpayer_Zip_Code'] = df_ftact['Taxpayer_Zip_Code'].astype(np.int64)
df_ftact['SOS_Charter_Date'] = df_ftact['SOS_Charter_Date'].astype(np.int64)
df_ftact['SOS_Status_Date'] = df_ftact['SOS_Status_Date'].astype(np.int64)
df_ftact['Responsibility_Beginning_Date'] = df_ftact['Responsibility_Beginning_Date'].astype(np.int64)
df_ftact['Secretary_of_State_File_Number'] = df_ftact['Secretary_of_State_File_Number'].astype(np.int64)
df_ftact['NAICS_Code'] = df_ftact['NAICS_Code'].astype(np.int64)
df_ftact['Current_Exempt_Reason_Code'] = df_ftact['Current_Exempt_Reason_Code'].astype(np.int64)

df_ftact['SOS_Charter_Date'] = pd.to_datetime(df_ftact["SOS_Charter_Date"], format='%Y%m%d', errors='coerce')
df_ftact['SOS_Status_Date'] = pd.to_datetime(df_ftact["SOS_Status_Date"], format='%Y%m%d', errors='coerce')
df_ftact['Responsibility_Beginning_Date'] = pd.to_datetime(df_ftact["Responsibility_Beginning_Date"], format='%Y%m%d', errors='coerce')

df_ftact['SOS_Charter_Date'] = df_ftact['SOS_Charter_Date'].dt.normalize()
df_ftact['SOS_Status_Date'] = df_ftact['SOS_Status_Date'].dt.normalize()
df_ftact['Responsibility_Beginning_Date'] = df_ftact['Responsibility_Beginning_Date'].dt.normalize()

df_ftact = df_ftact[df_ftact['Taxpayer_Zip_Code']!=0]
df_ftact.head()
# Out:
#    Taxpayer_Number               Taxpayer_Name  \
# 0      10004813456  MARSHALL E HAMILTON MD PA.
# 1      10058125732        CAP INVESTMENT GROUP
# 2      10082832105          JDM RESOURCES, LTD
# 3      10100464006             CLARK INSURANCE
# 4      10100798122  FIASCHETTI ENTERPRISES, LP
#
#                   Taxpayer_Address Taxpayer_City Taxpayer_State  \
# 0  PO BOX 38206 C/O STEVE WINN CPA        DALLAS             TX
# 1           1801 HINKLE DR STE 150        DENTON             TX
# 2                 5105 BUCKLAND DR      MCKINNEY             TX
# 3           1945 CONGRESS ST STE A      PORTLAND             ME
# 4                      5610 5TH ST          KATY             TX
#
#    Taxpayer_Zip_Code  Taxpayer_County_Code Taxpayer_Organizational_Type  \
# 0              75238                    57                           AP
# 1              76201                    61                           PB
# 2              75070                    43                           PL
# 3               4102                     0                           CF
# 4              77493                   101                           PL
#
#   Taxpayer_Phone_Number Record_Type_Code  ... SOS_Status_Code  \
# 0            9726442142                X  ...             NaN
# 1            9408914223                X  ...             NaN
# 2            2145440124                X  ...             NaN
# 3            2075232218                V  ...               A
# 4            8329717661                U  ...               R
#
#    Rigth_to_Tansact_Business_Code  Current_Exempt_Reason_Code  \
# 0                               A                           0
# 1                               A                           0
# 2                               A                           0
# 3                               A                           0
# 4                               A                           0
#
#    Exempt_Begin_Date NAICS_Code    Taxpayer_Organizational_Name  \
# 0                NaN     621111  Texas Professional Association
# 1                NaN     551112    Business General Partnership
# 2                NaN     525990       Texas Limited Partnership
# 3                NaN          0                  Foreign Profit
# 4                NaN          0       Texas Limited Partnership
#
#                                  Record_Type_Name  \
# 0                Comptroller Assigned File Number
# 1                Comptroller Assigned File Number
# 2                Comptroller Assigned File Number
# 3  SOS Certificate of Authority (COA) File Number
# 4            Secretary of State (SOS) File Number
#
#            Responsibility_End_Reason_Name  SOS_Status_Name  \
# 0  Active or Inactive with no Reason Code              NaN
# 1  Active or Inactive with no Reason Code              NaN
# 2  Active or Inactive with no Reason Code              NaN
# 3  Active or Inactive with no Reason Code           Active
# 4  Active or Inactive with no Reason Code       Reinstated
#
#    Rigth_to_Tansact_Business_Name
# 0                          Active
# 1                          Active
# 2                          Active
# 3                          Active
# 4                          Active
#
# [5 rows x 26 columns]

# %% [markdown]
# # FTOFFDIR DF created

# %%
df_ftoffdir.head()

# %% [markdown]
# #### Formating data
# * changing float to int

# %%
df_ftoffdir['Director_Latest_Year_Filed'] = df_ftoffdir['Director_Latest_Year_Filed'].fillna(0)
df_ftoffdir['Director_Latest_Year_Filed'] = df_ftoffdir['Director_Latest_Year_Filed'].astype(np.int64)
df_ftoffdir.head()

# %% [markdown]
# ## Upload DF's to Database
# * Adding database connection
# * Defining the Engine
# ** I was getting charmap error when attempting to drop the data to the database. I defined encoding = utf-8, yet it still did not work. Only when I hardcoded charset within the engine string is when the error finally went away.

# %%
connection_string = f"{mysql_user}:{mysql_password}@localhost:3306/{db_name}?charset=utf8"
engine = create_engine(f'mysql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['ccim',
#  'franchise_tax_info',
#  'franchise_tax_info_date',
#  'ftoffdir',
#  'sales_tax_info',
#  'sales_tax_info_date']

# %% [markdown]
# #### Creating two variables for today's date and today's datetime

# %%
currentDT = datetime.datetime.now()
DateTimeSent = currentDT.strftime("%Y-%m-%d %H:%M:%S")
dateCSV = currentDT.strftime("%Y-%m-%d")
print(dateCSV)
print(DateTimeSent)
# Out:
# 2020-03-25
# 2020-03-25 02:13:35

# %% [markdown]
# ## Calling Database tables for crosreferencing df data, to have non-duplicated data
# * Grabing data from the database and storing the tax number column into a dataframe

# %%
ftact_in_db = pdsql.read_sql("SELECT Taxpayer_Number FROM franchise_tax_info",engine)
stact_in_db = pdsql.read_sql("SELECT Taxpayer_Number FROM sales_tax_info", engine)
ftoffdir_in_db = pdsql.read_sql("SELECT Taxpayer_Number FROM ftoffdir", engine)


print(f"Data count for ftact from the database : {len(ftact_in_db)}\nData count for stact from the Database: {len(stact_in_db)}\nData count for ftoffdir from the Database: {len(ftoffdir_in_db)}")

try:
    if df_fran.size != 0:
        print(f"\nData count from the new df data for df_fran: {len(df_fran)}")
except Exception as e:
    print("df_fran does not exist. Check your data source if it is available")
    
try:
    if df_stp.size != 0:
        print(f"Data count from the new df data for df_stp: {len(df_stp)}")
except Exception as e:
    print("df_stp does not exist. Check your data source if it is available")
    
try:
    if df_ftact.size != 0:
        print(f"Data count from the new df data for df_ftact: {len(df_ftact)}")
except Exception as e:
    print("df_ftact does not exist. Check your data source if it is available")
    
try:
    if df_stact.size != 0:
        print(f"Data count from the new df data for df_stact: {len(df_stact)}")
except Exception as e:
    print("df_stact does not exist. Check your data source if it is available")
    
try:
    if df_ftoffdir.size != 0:
        print(f"Data count from the new df data for df_ftoffdir: {len(df_ftoffdir)}")
except Exception as e:
    print("df_ftoffdir does not exist. Check your data source if it is available")
# Out:
# Data count for ftact from the database : 0
# Data count for stact from the Database: 0
# Data count for ftoffdir from the Database: 0
# Data count from the new df data for df_ftact: 4236082
# Data count from the new df data for df_stact: 1554488
# df_ftoffdir does not exist. Check your data source if it is available

# %% [markdown]
# ## FTACT aka df_ftact
# #### Checking table df with df data to make sure their are not duplicate tax paying numbers
# * filtering new ftact with data from the database
# * Checking data for ftact and also adding a new column of today's date and time
# * Appending new companies (df_ftact) to  csv and Database

# %%
try:
    df_ftact = df_ftact[~df_ftact['Taxpayer_Number'].astype(int).isin(ftact_in_db['Taxpayer_Number'].astype(int))]
    if df_ftact.size != 0:
        df_ftact['DateTime'] = DateTimeSent
        print(f"There are {len(ftact_in_db)} data attributes in ftact table from the database\n{len(df_ftact)} new companies, based on tax payer number from filtered data df_tact")
        formattedData = os.path.abspath('HotelOccupancyTaxData/formattedData/'+ 'ftact_' + dateCSV + '.csv')
        df_ftact.to_csv(formattedData, index = False)
        df_ftact.to_sql(name='franchise_tax_info', con=engine, if_exists='append', index=False, chunksize=1000)
        print(f"ftact to database append, completed")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'{DateTimeSent}\nftact_{dateCSV}.csv, {len(df_ftact)}, franchise_tax_info table, {len(ftact_in_db)}\n')
        f.close()
    else:
        print("No new data")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'{DateTimeSent}\nftact_{dateCSV}.csv, {len(df_ftact)}, franchise_tax_info table, {len(ftact_in_db)}\n')
        f.close()
except Exception as e:
    print(f"Something went wrong, df_ftact was not able to append to database or no new data: {e}")
# Out:
# There are 0 data attributes in ftact table from the database
# 4236082 new companies, based on tax payer number from filtered data df_tact
# ftact to database append, completed

# %% [markdown]
# ## STACT aka df_stact
# #### Checking table df with df data to make sure their are not duplicate tax paying numbers
# * filtering new stact with data from the database
# * Checking data for stact and also adding a new column of today's date and time
# * Appending new companies (df_stact) to  csv and Database

# %%
try:
    df_stact = df_stact[~df_stact['Taxpayer_Number'].astype(int).isin(stact_in_db['Taxpayer_Number'].astype(int))]
    if df_stact.size != 0:
        df_stact['DateTime'] = DateTimeSent
        print(f"There are {len(stact_in_db)} data attributes in stact table from the database\n{len(df_stact)} new companies, based on tax payer number from filtered data sf_tact")
        formattedData = os.path.abspath('HotelOccupancyTaxData/formattedData/'+ 'stact_' + dateCSV + '.csv')
        df_stact.to_csv(formattedData, index = False)
        df_stact.to_sql(name='sales_tax_info', con=engine, if_exists='append', index=False, chunksize=1000)
        print(f"stact to database append, completed")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'stact_{dateCSV}.csv, {len(df_stact)}, sales_tax_info table, {len(stact_in_db)}\n')
        f.close()
    else:
        print("No new data")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'stact_{dateCSV}.csv, {len(df_stact)}, sales_tax_info table, {len(stact_in_db)}\n')
        f.close()
except Exception as e:
    print(f'No new data for STACT: {e}')
# Out:
# There are 0 data attributes in stact table from the database
# 1554488 new companies, based on tax payer number from filtered data sf_tact
# stact to database append, completed

# %% [markdown]
# ## FTOFFDIR aka df_ftoffdir
# #### Checking table df with df data to make sure their are not duplicate tax paying numbers
# * filtering new ftoffdir with data from the database
# * Checking data for ftoffdir and also adding a new column of today's date and time
# * Appending new companies (ftoffdir) to  csv and Database

# %%
try:
    df_ftoffdir = df_ftoffdir[~df_ftoffdir['Taxpayer_Number'].astype(int).isin(ftoffdir_in_db['Taxpayer_Number'].astype(int))]
    if df_ftoffdir.size != 0:
        df_ftoffdir['DateTime'] = DateTimeSent
        print(f"There are {len(ftoffdir_in_db)} data attributes in ftoffdir table from the database\n{len(df_ftoffdir)} new companies, based on tax payer number from filtered data df_ftoffdir")
        formattedData = os.path.abspath('HotelOccupancyTaxData/formattedData/'+ 'df_ftoffdir_' + dateCSV + '.csv')
        df_ftoffdir.to_csv(formattedData, index = False)
        df_ftoffdir.to_sql(name='ftoffdir', con=engine, if_exists='append', index=False, chunksize=1000)
        print(f"ftoffdir to database append, completed")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'df_ftoffdir_{dateCSV}.csv, {len(df_ftoffdir)}, ftoffdir table, {len(ftoffdir_in_db)}\n')
        f.close()
    else:
        print("No new data")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'df_ftoffdir_{dateCSV}.csv, {len(df_ftoffdir)}, ftoffdir table, {len(ftoffdir_in_db)}\n')
        f.close()
except Exception as e:
    print(f"Something went wrong, df_ftoffdir was not able to append to database: {e}")

# %% [markdown]
# ## Call the tables within the database and store into a variable
# * Going to compare new data from database with the df_fran and df_stp to filter

# %%
ftact_date_in_db = pdsql.read_sql("SELECT Taxpayer_Number FROM franchise_tax_info_date",engine)
stact_date_in_db = pdsql.read_sql("SELECT Taxpayer_Number FROM sales_tax_info_date",engine)
print(f"There are {len(ftact_date_in_db)} records in frachise tax permit date table.\nThere are {len(stact_date_in_db)} records in sales tax permit date table. ")
# Out:
# There are 0 records in frachise tax permit date table.
# There are 0 records in sales tax permit date table.

# %% [markdown]
# ## fran aka df_fran
# #### Checking table df with df data to make sure their are not duplicate tax paying numbers
# * filtering new df_fran with data from the database
# * Checking data for df_fran and also adding a new column of today's date and time
# * Appending new companies (fran) to  csv and Database

# %%
try:
    df_fran = df_fran[~df_fran['Taxpayer_Number'].astype(int).isin(ftact_date_in_db['Taxpayer_Number'].astype(int))]
    if df_fran.size != 0:
        df_fran['DateTime'] = DateTimeSent
        print(f"There are {len(ftact_date_in_db)} data attributes in df_fran table from the database\n{len(df_fran)} new companies, based on tax payer number from filtered data df_fran")
        formattedData = os.path.abspath('HotelOccupancyTaxData/formattedData/'+ 'df_fran' + dateCSV + '.csv')
        df_fran.to_csv(formattedData, index = False)
        df_fran.to_sql(name='franchise_tax_info_date', con=engine, if_exists='append', index=False, chunksize=1000)
        print(f"df_fran to database append, completed")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'fran_{dateCSV}.csv, {len(df_fran)}, franchise_tax_info_date table, {len(ftact_date_in_db)}\n')
        f.close()
    else:
        print("No new data")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'fran_{dateCSV}.csv, {len(df_fran)}, franchise_tax_info_date table, {len(ftact_date_in_db)}\n')
        f.close()
except Exception as e:
    print(f"Something went wrong, df_fran was not able to append to database: {e}")
# Out:
# There are 0 data attributes in df_fran table from the database
# 111888 new companies, based on tax payer number from filtered data df_fran
# df_fran to database append, completed

# %% [markdown]
# <!-- #### Appending new companies (fran) to  csv and Database -->

# %% [markdown]
# ## stp aka df_stp
# #### Checking table df with df data to make sure their are not duplicate tax paying numbers
# * filtering new df_stp with data from the database
# * Checking data for df_stp and also adding a new column of today's date and time
# * Appending new companies (stp) to  csv and Database

# %%
try:
    df_stp = df_stp[~df_stp['Taxpayer_Number'].astype(int).isin(stact_date_in_db['Taxpayer_Number'].astype(int))]
    if df_stp.size != 0:
        df_stp['DateTime'] = DateTimeSent
        print(f"There are {len(stact_date_in_db)} data attributes in df_stp table from the database\n{len(df_stp)} new companies, based on tax payer number from filtered data df_fran")
        formattedData = os.path.abspath('HotelOccupancyTaxData/formattedData/'+ 'df_stp' + dateCSV + '.csv')
        df_stp.to_csv(formattedData, index = False)
        df_stp.to_sql(name='sales_tax_info_date', con=engine, if_exists='append', index=False, chunksize=1000)
        print(f"df_stp to database append, completed")
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'stp_{dateCSV}.csv, {len(df_stp)}, sales_tax_info_date table, {len(stact_date_in_db)}\n---------------------end---------------------\n\n')
        f.close()
    else:
        print('No new data')
        f = open('HotelOccupancyTaxData/formattedData/DBUploadRecord.txt','a+')
        f.write(f'stp_{dateCSV}.csv, {len(df_stp)}, sales_tax_info_date table, {len(stact_date_in_db)}\n---------------------end---------------------\n\n')
        f.close()
except Exception as e:
    print(f"Something went wrong, df_stp was not able to append to database: {e}")
# Out:
# There are 0 data attributes in df_stp table from the database
# 54254 new companies, based on tax payer number from filtered data df_fran
# df_stp to database append, completed
